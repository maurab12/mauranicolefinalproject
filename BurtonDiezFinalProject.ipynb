# %% [markdown]
# <a href="https://colab.research.google.com/github/maurab12/mauranicolefinalproject/blob/main/BurtonDiezFinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # City of Chicago Current Employee Names, Salaries, and Position Titles

# %% [markdown]
# # Why did we pick the dataset?
# ---
# - We are from the Northern suburbs of Chicago
# - We both want to live and work in Chicago after graduation
# - We find it interesting to learn the positions and salaries that they recieve as we soon be in their shoes

# %% [markdown]
# # Questions?
# ---
# - What is the highest paying full-time position?
# - What is the lowest paying full-time position?
# - What is the distribution of salaries?
# - What position has the most employees?
# - Whar are the top 10 common department?
# - What is the least common positio?

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px

# %%
df = pd.read_csv("https://github.com/maurab12/mauranicolefinalproject/blob/main/Current_Employee_Names__Salaries__and_Position_Titles%20(1).csv?raw=true")
display(df)
# Out:
#                       Name  ... Hourly Rate
# 0        AARON,  JEFFERY M  ...         NaN
# 1           AARON,  KARINA  ...         NaN
# 2      AARON,  KIMBERLEI R  ...         NaN
# 3      ABAD JR,  VICENTE M  ...         NaN
# 4        ABARCA,  EMMANUEL  ...        44.4
# ...                    ...  ...         ...
# 31853   ZYLINSKA,  KLAUDIA  ...         NaN
# 31854   ZYMANTAS,  LAURA C  ...         NaN
# 31855    ZYMANTAS,  MARK E  ...         NaN
# 31856  ZYRKOWSKI,  CARLO E  ...         NaN
# 31857  ZYSKOWSKI,  DARIUSZ  ...         NaN
#
# [31858 rows x 8 columns]

# %% [markdown]
# ## The Number of Rows and Columns

# %%
num_rows = df.shape[0]
num_cols = df.shape[1]

print(num_rows)
print(num_cols)
# Out:
# 31858
# 8

# %% [markdown]
# ##Concise summary of our DataFrame

# %%
df.info
display(df)
# Out:
#                       Name  ... Hourly Rate
# 0        AARON,  JEFFERY M  ...         NaN
# 1           AARON,  KARINA  ...         NaN
# 2      AARON,  KIMBERLEI R  ...         NaN
# 3      ABAD JR,  VICENTE M  ...         NaN
# 4        ABARCA,  EMMANUEL  ...        44.4
# ...                    ...  ...         ...
# 31853   ZYLINSKA,  KLAUDIA  ...         NaN
# 31854   ZYMANTAS,  LAURA C  ...         NaN
# 31855    ZYMANTAS,  MARK E  ...         NaN
# 31856  ZYRKOWSKI,  CARLO E  ...         NaN
# 31857  ZYSKOWSKI,  DARIUSZ  ...         NaN
#
# [31858 rows x 8 columns]

# %% [markdown]
# ## Filtering our DataFrame to only Full-Time Worker

# %%
df_fulltime = df[(df['Full or Part-Time'] == 'F')]
df_fulltime
# Out:
#                       Name  ... Hourly Rate
# 0        AARON,  JEFFERY M  ...         NaN
# 1           AARON,  KARINA  ...         NaN
# 2      AARON,  KIMBERLEI R  ...         NaN
# 3      ABAD JR,  VICENTE M  ...         NaN
# 4        ABARCA,  EMMANUEL  ...        44.4
# ...                    ...  ...         ...
# 31853   ZYLINSKA,  KLAUDIA  ...         NaN
# 31854   ZYMANTAS,  LAURA C  ...         NaN
# 31855    ZYMANTAS,  MARK E  ...         NaN
# 31856  ZYRKOWSKI,  CARLO E  ...         NaN
# 31857  ZYSKOWSKI,  DARIUSZ  ...         NaN
#
# [30591 rows x 8 columns]

# %% [markdown]
# ##Dropping Typical Hours and Hourly Rate Columns & Renaming Columns

# %%
df_fulltime.drop(columns=['Typical Hours', 'Hourly Rate'], inplace = True)
df_fulltime.rename(columns={'Full or Part-Time': 'Full-Time'}, inplace = True)
df_fulltime.rename(columns={'Salary or Hourly': 'Salary'}, inplace = True)
df_fulltime
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                       Name  ... Annual Salary
# 0        AARON,  JEFFERY M  ...      118998.0
# 1           AARON,  KARINA  ...       97440.0
# 2      AARON,  KIMBERLEI R  ...      121272.0
# 3      ABAD JR,  VICENTE M  ...      119712.0
# 4        ABARCA,  EMMANUEL  ...           NaN
# ...                    ...  ...           ...
# 31853   ZYLINSKA,  KLAUDIA  ...       76266.0
# 31854   ZYMANTAS,  LAURA C  ...       80016.0
# 31855    ZYMANTAS,  MARK E  ...       90024.0
# 31856  ZYRKOWSKI,  CARLO E  ...       93354.0
# 31857  ZYSKOWSKI,  DARIUSZ  ...      135336.0
#
# [30591 rows x 6 columns]

# %%
df.head
# Out:
# <bound method NDFrame.head of                       Name  ... Hourly Rate
# 0        AARON,  JEFFERY M  ...         NaN
# 1           AARON,  KARINA  ...         NaN
# 2      AARON,  KIMBERLEI R  ...         NaN
# 3      ABAD JR,  VICENTE M  ...         NaN
# 4        ABARCA,  EMMANUEL  ...        44.4
# ...                    ...  ...         ...
# 31853   ZYLINSKA,  KLAUDIA  ...         NaN
# 31854   ZYMANTAS,  LAURA C  ...         NaN
# 31855    ZYMANTAS,  MARK E  ...         NaN
# 31856  ZYRKOWSKI,  CARLO E  ...         NaN
# 31857  ZYSKOWSKI,  DARIUSZ  ...         NaN
#
# [31858 rows x 8 columns]>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                       Name  ... Hourly Rate
# 0        AARON,  JEFFERY M  ...         NaN
# 1           AARON,  KARINA  ...         NaN
# 2      AARON,  KIMBERLEI R  ...         NaN
# 3      ABAD JR,  VICENTE M  ...         NaN
# 4        ABARCA,  EMMANUEL  ...        44.4
# ...                    ...  ...         ...
# 31853   ZYLINSKA,  KLAUDIA  ...         NaN
# 31854   ZYMANTAS,  LAURA C  ...         NaN
# 31855    ZYMANTAS,  MARK E  ...         NaN
# 31856  ZYRKOWSKI,  CARLO E  ...         NaN
# 31857  ZYSKOWSKI,  DARIUSZ  ...         NaN
#
# [31858 rows x 8 columns]>

# %%
df.sample(8)
# Out:
#                        Name  ... Hourly Rate
# 21793      PEARCE,  JAWAUNE  ...       26.73
# 13554     JOHNSON,  BOBBY J  ...       38.35
# 882      ANTHONY,  STEVEN C  ...       38.35
# 2786    BRASHEAR,  CONNOR A  ...         NaN
# 12215         HILL,  NATOYA  ...         NaN
RUCK DRIVER", "MANAGING DEPUTY COMMISSIONER", "PARAMEDIC I/C", "FIREFIGHTER-EMT (RECRUIT)", "PARAMEDIC", "STEAMFITTER", "EEO INVESTIGATOR", "FIREFIGHTER-EMT (RECRUIT)", "WINDOW WASHER", "POLICE OFFICER", "POLICE OFFICER", "POLICE OFFICER", "MACHINIST (AUTOMOTIVE)", "FREEDOM OF INFORMATION ACT OFFICER", "POLICE OFFICER", "POLICE OFFICER", "LIBRARY ASSOCIATE", "POLICE OFFICER", "POLICE OFFICER", "SANITATION LABORER", "PARKING ENFORCEMENT AIDE", "LABORER", "POLICE OFFICER", "FIREFIGHTER-EMT (RECRUIT)", "POLICE OFFICER", "SANITATION LABORER", "BOOTER - PARKING", "POLICE OFFICER", "MACHINIST (AUTOMOTIVE)", "CUSTODIAL WORKER", "POLICE OFFICER", "POLICE OFFICER (ASSIGNED AS DETECTIVE)", "FIREFIGHTER/PARAMEDIC", "FIREFIGHTER-EMT", "LAMP MAINTENANCE WORKER", "SPECIAL EVENTS COORD III", "REGIONAL LIBRARY DIRECTOR", "CLINICAL THERAPIST III", "POLICE OFFICER", "SANITATION LABORER", "AVIATION SECURITY OFFICER", "POLICE OFFICER", "POLICE OFFICER", "POOL MOTOR TRUCK DRIVER", "POLICE OFFICER (ASSIGNED AS DETECTIVE)", "POLICE OFFICER", "FIREFIGHTER-EMT", "POLICE OFFICER", "POLICE OFFICER", "FIREFIGHTER-EMT", "POLICE OFFICER", "PROGRAM AUDITOR II", "POLICE OFFICER", "WATCHMAN", "LEGAL SECRETARY", "MOTOR TRUCK DRIVER", "SR PROCUREMENT SPECIALIST", "CAPTAIN-EMT", "VENTILATION AND FURNACE INSPECTOR", "POLICE OFFICER", "GENERAL LABORER - DSS", "LIBRARIAN IV", "SUPVSR OF COMPENSATION", "CIVIL ENGINEER IV", "PUBLIC HEALTH ADMINISTRATOR I", "POLICE OFFICER (ASSIGNED AS DETECTIVE)", "POLICE OFFICER", "POLICE OFFICER", "SERGEANT", "CONCRETE LABORER", "POOL MOTOR TRUCK DRIVER", "LIBRARY CLERK", "LIBRARY ASSOCIATE", "BUILDING/CONSTRUCTION INSPECTOR", "POLICE OFFICER", "SUPERVISING DISEASE CONTROL INVESTIGATOR - EXCL", "POLICE OFFICER", "LEGISLATIVE AIDE", "FREEDOM OF INFORMATION ACT OFFICER", "LEAD ACCOUNTANT", "AVIATION SECURITY OFFICER", "ENVIRONMENTAL ENGINEER III", "ELECTRICAL MECHANIC (AUTOMOTI ...

# %% [markdown]
# ##What is the Least Common Job Title?

# %%
fig = px.pie(
    df_fulltime,
    names='Job Titles',
    title='Job Titles breakdown',
    width=1200,
    height=1000
# Out:
#   File "<ipython-input-12-3966f7f75b2c>", line 6
#     height=1000
#                ^
# SyntaxError: unexpected EOF while parsing
